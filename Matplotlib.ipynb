# %%
import matplotlib.pyplot as plt
a=[1,2,3,2,3,2,7]
b=['a','b','c','d','e','f','g']
plt.bar(b,a,color=['r','g','b','r','g','b','black'])
plt.title('CLASS XII')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("gb.csv")
df.plot(kind='line', color=['m','black','b','r','g'])
plt.title('CLASS XII')
plt.show()

# %%
a=[100,2000,3000,456,854,856,2958937]
b=['Aryan','Bhavesh','Ananay','Om','Vansh','Vedant','XYZ']
