# %%
import matplotlib.pyplot as plt
a=[1,2,3,2,3,2,7]
b=['a','b','c','d','e','f','g']
plt.bar(b,a,color=['r','g','b','r','g','b','black'])
plt.title('CLASS XII')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("gb.csv")
df.plot(kind='line', color=['m','black','b','r','g'])
plt.title('CLASS XII')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,50,100,200]
y=[5,15,25,35]
plt.plot(x,y,color='m',linewidth=10)
plt.title("Line Plot",fontsize=20,color='b')
plt.xlabel("Distance")
plt.ylabel("Time")
plt.show()

# %%
                                                                                                               import matplotlib.pyplot as plt
Partition = 'Holidays', 'Eating_Out', 'Shopping', 'Groceries'
sizes = [250, 100, 300, 200]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=Partition, autopct='%1.1f%%', shadow=True, startangle=90)         
ax1.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
marks=[80,90,100,80,40,50,60]
bin=[1,33,45,60,75,90,100]
y=[0,1,2,3,4,5,6]
weight=[2,2,2,2,2,2,2]
plt.hist(marks,bins=bin,weights=weight,color='m',edgecolor='b',
        hatch='*',linestyle='--',fill=False,orientation='vertical')
plt.xlabel('No. of students')
plt.ylabel('Marks')
plt.title('HISTOGRAM PLOT')
plt.yticks(y)
plt.show()

# %% [markdown]
# # Q A servey gathers height and weight of 100 participants
# # and  recorded  the  participants  age as 1 2 3 4 .. 100  ages
# # write a program to plot a histogram from the data with 20 bins.

# %%
import numpy as np
import matplotlib.pyplot as plt
age=np.arange(1,101)
weight=np.random.randint(50,100,100)
height=np.random.randint(163,190,100)
bins=np.arange(1,200,10)
plt.hist(age,bins=bins,fill=False,edgecolor='r')
plt.hist(height,bins=bins,fill=False,edgecolor='b')
plt.hist(weight,bins=bins,fill=False,edgecolor='g')
plt.legend(["age","weight","height"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter


# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20

# Creating distribution
x = np.random.randn(N_points)
y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
						figsize =(10, 7),
						tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.6)

# Add Text watermark
fig.text(0.9, 0.15, 'VENI VIDI VICI',
		fontsize = 12,
		color ='red',
		ha ='right',
		va ='bottom',
		alpha = 0.7)

# Creating histogram
N, bins, patches = axs.hist(x, bins = n_bins)

# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())

for thisfrac, thispatch in zip(fracs, patches):
	color = plt.cm.viridis(norm(thisfrac))
	thispatch.set_facecolor(color)

# Adding extra features
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
means=[20,35,30,35,27]
stds=[2,3,4,1,2]
indx=np.arange(len(means))
plt.barh(indx,means,color='c',label='means')
plt.barh(indx+0.25,stds,color='olive',label='stds')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,10)
y=np.random.randint(10,size=(10,))
z=np.random.randint(50,size=(10,))
plt.figure(figsize=(8,4))
plt.plot(x,y,label='OP')
plt.plot(x,z,label='VICI')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
X=[1,2,3,4]
Y=[10,20,25,30]
A=[0.3,3.8,1.2,2.5]
B=[11,25,9,26]
plt.plot(X,Y,color='b',linewidth=3)
plt.scatter(A,B,color='m',marker='^')
plt.show()
